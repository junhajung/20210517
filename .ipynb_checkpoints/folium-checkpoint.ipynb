# %%
# 지도 표시하기
! pip install folium

# %%
import csv

# 파일 읽기 (euc-kr)
file = open('csv/부산광역시_해운대구_도시공원_20201215_1608034363405_11422.csv', 'r', encoding="euc-kr")
rdr = csv.reader(file)

# 읽은 파일 내용 보기
for tmp in rdr:
    print(tmp)
# Out:
# ['관리번호', '공원명', '공원구분', '소재지도로명주소', '소재지지번주소', '위도', '경도', '공원면적', '공원보유시설(운동시설)', '공원보유시설(유희시설)', '공원보유시설(편익시설)', '공원보유시설(교양시설)', '공원보유시설(기타시설)', '지정고시일', '관리기관명', '전화번호', '데이터기준일자']
# ['26350-00001', 'APEC나루공원', '근린공원', '부산광역시 해운대구 수영강변대로 93', '부산광역시 해운대구 우동 1494', '35.16864139', '129.1260362', '99999.3', '', '', '', '', '', '2000-08-10', '해운대구청 늘푸른과', '', '2020-12-15']
# ['26350-00002', '가온공원', '어린이공원', '', '부산광역시 해운대구 반여동 751-8', '35.2112867', '129.1169609', '2002', '', '', '', '', '', '2006-12-27', '해운대구청 늘푸른과', '', '2020-12-15']
# ['26350-00003', '거미줄공원', '어린이공원', '', '부산광역시 해운대구 좌동 1334', '35.1656385', '129.1791219', '1804', '', '', '', '', '', '1992-08-06', '해운대구청 늘푸른과', '', '2020-12-15']
# ['26350-00004', '견우공원', '어린이공원', '', '부산광역시 해운대구 좌동 1311', '35.1716798', '129.1800161', '1798.8', '', '', '', '', '', '1992-08-06', '해운대구청 늘푸른과', '', '2020-12-15']
# ...

# %%
import  pandas as pd # pandas, numpy

df = pd.read_csv('csv/부산광역시_해운대구_도시공원_20201215_1608034363405_11422.csv', encoding="euc-kr")
# df
# Out:
#            관리번호         공원명   공원구분                   소재지도로명주소  \
# 0   26350-00001    APEC나루공원   근린공원       부산광역시 해운대구 수영강변대로 93
# 1   26350-00002        가온공원  어린이공원                        NaN
# 2   26350-00003       거미줄공원  어린이공원                        NaN
# 3   26350-00004        견우공원  어린이공원                        NaN
# 4   26350-00005       구덕포공원    소공원                        NaN
# ..          ...         ...    ...                        ...
# 69  26350-00071        반송공원   근린공원                        NaN
# 70  26350-00072       청사포공원   수변공원                        NaN
# 71  26350-00073      대천산림공원   문화공원                        NaN
# 72  26350-00074  해운대역사 시민공원   문화공원    부산광역시 해운대구 해운대로 621(우동)
# 73  26350-00075       동백유원지     기타  부산광역시 해운대구 해운대해변로 220(우동)
#
#                   소재지지번주소         위도          경도      공원면적  공원보유시설(운동시설)  \
# 0      부산광역시 해운대구 우동 1494  35.168641  129.126036   99999.3           NaN
# ...
