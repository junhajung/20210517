# %%
from selenium import webdriver
import bs4 # pip install bs4
import time


url = "https://shoppinghow.kakao.com/top"

# 옵션설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")    
# options.add_argument("headless") # 크롬창이 표시되지 않음
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent 

# 드라이브 로딩
driver = webdriver.Chrome(executable_path="driver/chromedriver.exe", options = options)
# 페이지 접속
driver.get(url)

# 로딩되는 시간이 있으므로 1초 기다림
time.sleep(2) 

# 로딩된 html 가져오기
response = driver.page_source

# 크롬창 닫기
driver.close()

# html을 bs4로 파싱하기
soup = bs4.BeautifulSoup(response, "html.parser")

# for tmp in soup.select('div#topRecomKeywordWrap'):
#     for tmp1 in soup.select("li", limit=10):
#         print(tmp1.text.strip())

# select + find_all => 여러개 => list
# select_one = find => 첫 번째 요소 1개 => 리스트 x

for tmp in soup.select('div#topRecomKeywordWrap'):
    for tmp1 in tmp.select("li"):
        print(tmp1.select_one("strong > a").text)
        print(tmp1.select_one(".num_price").text)
        print(tmp1.select_one(".tit_g").text)
        print("-" * 30)
        
        
        
a = [1,2,3,4,5]
for tmp in a:
    print(tmp)

for idx, tmp in enumerate(a): # 인덱스 위치까지 함께 출력
    print(idx, tmp)
# Out:
# 1 . 피쉬콜라겐
# 43,430
# 저분자 피쉬 콜라겐 펩타이드 90포
# ------------------------------
# 2 . 린넨자켓
# 19,000
# [F.N] 에프엔 프렌치 린넨자켓 K182
# ------------------------------
# 3 . 차량에어컨탈취제
# 8,300
# 에어컨필터 방향제
# ------------------------------
# 4 . 캠핑롤테이블
# 44,300
# 뮐러 접이식 캠핑 롤테이블
# ------------------------------
# 5 . 참치회
# 54,220
# 슬라이스 냉동 참치회 참다랑어 배꼽살 통앞뱃살
# ------------------------------
# 6 . 곰팡이제거제
# 4,750
# 곰팡이 제거제 본품 500ml+리필 500ml
# ------------------------------
# 7 . 자몽
# 27,120
# 후레쉬데이 미국 플로리다 자몽 중 개당 300g내외 20과
# ------------------------------
# 8 . 세발자전거
# 79,390
# 버기트라이크 멀티 폴딩 접이식 세발자전거
# ------------------------------
# 9 . 가정용불판테이블
# 121,350
# 소담갤러리 우드슬랩 4인용 가정용 불판 테이블 미우새 김건모
# ------------------------------
# 10 . 스텝퍼
# 55,860
# 트위스트 스탭퍼 [7120]
# ------------------------------
# 1
# 2
# 3
# 4
# 5
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %%
from selenium import webdriver
import bs4 # pip install bs4
import time

import urllib.request as REQ# 서버 요청

url = "https://shoppinghow.kakao.com/top"

# 옵션설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")    
# options.add_argument("headless") # 크롬창이 표시되지 않음
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent 

# 드라이브 로딩
driver = webdriver.Chrome(executable_path="driver/chromedriver.exe", options = options)
# 페이지 접속
driver.get(url)


# 로딩되는 시간이 있으므로 1초 기다림
time.sleep(2) 

for idx in range(1,11,1) :
        img = driver.find_element_by_xpath('//*[@id="topRecomKeywordWrap"]/div[2]/ul/li[' + str(idx) + ']/a/img')
        print(img.get_attribute("src"))
        
        # 서버요청 (이미지의 url주소, 저장할 파일명)
        REQ.urlretrieve(img.get_attribute("src"), f'download/image_{idx}.jpg')
        print("-" * 30)
        
driver.close()
# Out:
# https://shop2.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop2.daumcdn.net%2Fshophow%2Fp%2FB5099244419.jpg%3Fut%3D20201029223837
# ------------------------------
# https://shop2.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop2.daumcdn.net%2Fshophow%2Fp%2FS13208837421.jpg%3Fut%3D20210512110838
# ------------------------------
# https://shop2.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop2.daumcdn.net%2Fshophow%2Fp%2FC5094273787.jpg%3Fut%3D20200601221011
# ------------------------------
# https://shop2.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop2.daumcdn.net%2Fshophow%2Fp%2FA5097328559.jpg%3Fut%3D20200821111120
# ------------------------------
# https://shop2.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop2.daumcdn.net%2Fshophow%2Fp%2FE5102338289.jpg%3Fut%3D20210404201213
# ------------------------------
# https://shop1.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop1.daumcdn.net%2Fshophow%2Fp%2FE5096603238.jpg%3Fut%3D20200706134848
# ------------------------------
# https://shop2.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop2.daumcdn.net%2Fshophow%2Fp%2FC5102089315.jpg%3Fut%3D20210312180139
# ------------------------------
# https://shop1.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop1.daumcdn.net%2Fshophow%2Fp%2FC5102417204.jpg%3Fut%3D20210409143008
# ------------------------------
# https://shop2.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop2.daumcdn.net%2Fshophow%2Fp%2FE5096821341.jpg%3Fut%3D20200720122911
# ------------------------------
# https://shop1.daumcdn.net/thumb/R250x250/?fname=https%3A%2F%2Fshop1.daumcdn.net%2Fshophow%2Fp%2FC22423532.jpg%3Fut%3D20190920114107
# ------------------------------

# %%
from selenium import webdriver
import bs4 # pip install bs4
import time
import urllib.request as REQ # 서버 요청
from selenium.webdriver.common.keys import Keys
import base64

url = "https://www.naver.com/"

# 옵션설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")    
# options.add_argument("headless") # 크롬창이 표시되지 않음
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent 

# 드라이브 로딩
driver = webdriver.Chrome(executable_path="driver/chromedriver.exe", options = options)
# 페이지 접속
driver.get(url)

time.sleep(1) 

# 크롬 자동화
driver.find_element_by_xpath('//*[@id="query"]').send_keys("사과")
driver.find_element_by_xpath('//*[@id="query"]').send_keys(Keys.ENTER)
driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[2]/a').click()

# 이미지 저장
for idx in range(1,6,1):
    time.sleep(1)
    try:
        img = driver.find_element_by_xpath(f'//*[@id="main_pack"]/section/div/div[1]/div[1]/div[{idx}]/div/div[1]/a/img')
        REQ.urlretrieve( img.get_attribute("src"), f'download/apple_{idx}.jpg' )
        print(img.get_attribute("src"))
        print("-" * 30)
    except Exception as e:
        print(e)

driver.close()
# Out:
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMTAyMTdfMjI0%2FMDAxNjEzNTU0MjE3Njkw.hps6L7AuGTP3DqnAj9AoZc3zZcp8Z8Vb-wPAwQuSRtQg.Nw2iK9rGS4FToDKjcBQOFNkhOjmwT1kJQs-KrJ2WItYg.JPEG.imhw3%2Fapple6.jpg&type=a340
# ------------------------------
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMTAzMjhfNjMg%2FMDAxNjE2OTAzNTM5NTE3.mWQxVc2e22xQ6zROdeBchHVTxZYpHpJiTAWdUid1sScg.jpBRbFtRjNnxKWOqxIMqZGLhNZgFJ6NL4VM1ZzYxxSIg.JPEG.gkskagml%2FKakaoTalk_20210328_124143495.jpg&type=a340
# ------------------------------
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMTA1MDJfMTIg%2FMDAxNjE5OTU4MjQ3NDQ3.UxY3ndPxHfTIyP9muJLOf5MZJLXQrs7RBRXBBRn9Mm8g.sJ2dgpw1ATNiN8rkiYluvvr-UCQQn9O2twmJl7LtaC0g.JPEG.guya62%2FScreenshot_20210501-212258_NAVER.jpg&type=a340
# ------------------------------
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMTA1MTFfMjMz%2FMDAxNjIwNzA5NjA3OTg2.urlvyDMC2-wHT6-JyZZnnLz6evtEh77cGGbQ9iRLszIg.wfvQhbIxFf2ZOaB258v2SGAk9YSNtM86aYuMyE28uyYg.JPEG.ipension%2F1620690213888.jpg&type=a340
# ------------------------------
# ...------------------------------

# %%
from selenium import webdriver
import bs4 # pip install bs4
import time
import urllib.request as REQ # 서버 요청
from selenium.webdriver.common.keys import Keys
import base64

url = "http://www.kyobobook.co.kr/index.laf?OV_REFFER=https://www.google.com/"

# 옵션설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")    
# options.add_argument("headless") # 크롬창이 표시되지 않음
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent 

# 드라이브 로딩
driver = webdriver.Chrome(executable_path="driver/chromedriver.exe", options = options)
# 페이지 접속
driver.get(url)

time.sleep(1) 

# 크롬 자동화
driver.find_element_by_xpath('//*[@id="searchKeyword"]').send_keys("파이썬")
driver.find_element_by_xpath('//*[@id="searchKeyword"]').send_keys(Keys.ENTER)

# 이미지 저장
for idx in range(1,11,1):
    img = driver.find_element_by_xpath(f'//*[@id="search_list"]/tr[{idx}]/td[1]/div[2]/a/img')
    REQ.urlretrieve( img.get_attribute("src"), f'download/python_{idx}.jpg' )
    print(img.get_attribute("src"))
    print("-" * 30)


driver.close()
# Out:
# https://simage.kyobobook.co.kr/images/book/large/882/l9791162241882.jpg
# ------------------------------
# https://simage.kyobobook.co.kr/images/book/large/911/l9791163030911.jpg
# ------------------------------
# https://simage.kyobobook.co.kr/images/book/large/077/l9791162243077.jpg
# ------------------------------
# https://simage.kyobobook.co.kr/images/book/large/033/l9791196918033.jpg
# ------------------------------
# https://simage.kyobobook.co.kr/images/book/large/811/l9791196608811.jpg
# ------------------------------
# https://simage.kyobobook.co.kr/images/book/large/178/l9791189909178.jpg
# ------------------------------
# https://simage.kyobobook.co.kr/images/book/large/573/l9788956748573.jpg
# ------------------------------
# https://simage.kyobobook.co.kr/images/book/large/928/l9791158391928.jpg
# ------------------------------
# https://simage.kyobobook.co.kr/images/book/large/719/l1400000345719.jpg
# ------------------------------
# https://simage.kyobobook.co.kr/images/book/large/169/l9791187431169.jpg
# ------------------------------

# %%
from selenium import webdriver  # pip install selenium
import time
from selenium.webdriver.common.keys import Keys
import bs4 # pip install bs4

url = "http://ihongss.com/webboard"

options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")  
# options.add_argument("headless")  # 크롬창이 표시되지 않음
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent 
driver = webdriver.Chrome(executable_path="driver/chromedriver.exe", options=options)
driver.get(url)
time.sleep(1) #1초 기다림

"""
<input type="text" name="email" value="" />
<input type="text" name="pw" value="" />
<script>
    document.getElementsByName('email')[0].value = 'b20221223';
    document.getElementsByName('pw')[0].value = 'b20201223';
    alert('로그인 되었음')
</script>
"""

driver.execute_script("document.getElementsByName('email')[0].value = 'b20201223'")
driver.execute_script("document.getElementsByName('pw')[0].value = 'b20201223'")
time.sleep(1)
driver.find_element_by_xpath('//*[@id="form1"]/div[3]/input').click()
driver.execute_script("alert('로그인 되었음!!')")

# %%
# 로그인 이후의 페이지 파싱하기
from selenium import webdriver  # pip install selenium
import time
from selenium.webdriver.common.keys import Keys
import bs4 # pip install bs4

url = "http://ihongss.com/webboard"

options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")  
# options.add_argument("headless")  # 크롬창이 표시되지 않음
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent 
driver = webdriver.Chrome(executable_path="driver/chromedriver.exe", options=options)
driver.get(url)
time.sleep(1) #1초 기다림

driver.execute_script("document.getElementsByName('email')[0].value = 'b20201223'")
driver.execute_script("document.getElementsByName('pw')[0].value = 'b20201223'")
time.sleep(1)
driver.find_element_by_xpath('//*[@id="form1"]/div[3]/input').click()


# 로그인 이후의 페이지 로딩된 html 가져오기
response = driver.page_source

# html을 bs4로 파싱하기
soup = bs4.BeautifulSoup(response, "html.parser")
soup
# Out:
# <html><head><style id="ace-eclipse">.ace-eclipse .ace_gutter {background: #ebebeb;border-right: 1px solid rgb(159, 159, 159);color: rgb(136, 136, 136);}.ace-eclipse .ace_print-margin {width: 1px;background: #ebebeb;}.ace-eclipse {background-color: #FFFFFF;color: black;}.ace-eclipse .ace_fold {background-color: rgb(60, 76, 114);}.ace-eclipse .ace_cursor {color: black;}.ace-eclipse .ace_storage,.ace-eclipse .ace_keyword,.ace-eclipse .ace_variable {color: rgb(127, 0, 85);}.ace-eclipse .ace_constant.ace_buildin {color: rgb(88, 72, 246);}.ace-eclipse .ace_constant.ace_library {color: rgb(6, 150, 14);}.ace-eclipse .ace_function {color: rgb(60, 76, 114);}.ace-eclipse .ace_string {color: rgb(42, 0, 255);}.ace-eclipse .ace_comment {color: rgb(113, 150, 130);}.ace-eclipse .ace_comment.ace_doc {color: rgb(63, 95, 191);}.ace-eclipse .ace_comment.ace_doc.ace_tag {color: rgb(127, 159, 191);}.ace-eclipse .ace_constant.ace_numeric {color: darkblue;}.ace-eclipse .ace_tag {color: rgb(25, 118, 116);}.ace-eclipse .ace_type {color: rgb(127, 0, 127);}.ace-eclipse .ace_xml-pe {color: rgb(104, 104, 91);}.ace-eclipse .ace_marker-layer .ace_selection {background: rgb(181, 213, 255);}.ace-eclipse .ace_marker-layer .ace_bracket {margin: -1px 0 0 -1px;border: 1px solid rgb(192, 192, 192);}.ace-eclipse .ace_meta.ace_tag {color:rgb(25, 118, 116);}.ace-eclipse .ace_invisible {color: #ddd;}.ace-eclipse .ace_entity.ace_other.ace_attribute-name {color:rgb(127, 0, 127);}.ace-eclipse .ace_marker-layer .ace_step {background: rgb(255, 255, 0);}.ace-eclipse .ace_active-line {background: rgb(232, 242, 254);}.ace-eclipse .ace_gutter-active-line {background-color : #DADADA;}.ace-eclipse .ace_marker-layer .ace_selected-word {border: 1px solid rgb(181, 213, 255);}.ace-eclipse .ace_indent-guide {background: url("...") right repeat-y;}
# /*# sourceURL=ace/css/ace-eclipse */</style><style>    .error_widget_wrapper {        background: inherit;        color: inherit;        border:none    }    .error_widget {        border-top: solid 2px;        border-bottom: solid 2px;        margin: 5px 0;        padding: 10px 40px;        white-space: pre-wrap;    }    .error_widget.ace_error, .error_widget_arrow.ace_error{        border-color: #ff5a5a    }    .error_widget.ace_warning, .error_widget_arrow.ace_warning{        border-color: #F1D817    }    .error_widget.ace_info, .error_widget_arrow.ace_info{        border-color: #5a5a5a    }    .error_widget.ace_ok, .error_widget_arrow.ace_ok{        border-color: #5aaa5a    }    .error_widget_arrow {        position: absolute;        border: solid 5px;        border-top-color: transparent!important;        border-right-color: transparent!important;        border-left-color: transparent!important;        top: -5px;    }</style><style id="ace-tm">.ace-tm .ace_gutter {background: #f0f0f0;color: #333;}.ace-tm .ace_print-margin {width: 1px;background: #e8e8e8;}.ace-tm .ace_fold {background-color: #6B72E6;}.ace-tm {background-color: #FFFFFF;color: black;}.ace-tm .ace_cursor {color: black;}.ace-tm .ace_invisible {color: rgb(191, 191, 191);}.ace-tm .ace_storage,.ace-tm .ace_keyword {color: blue;}.ace-tm .ace_constant {color: rgb(197, 6, 11);}.ace-tm .ace_constant.ace_buildin {color: rgb(88, 72, 246);}.ace-tm .ace_constant.ace_language {color: rgb(88, 92, 246);}.ace-tm .ace_constant.ace_library {color: rgb(6, 150, 14);}.ace-tm .ace_invalid {background-color: rgba(255, 0, 0, 0.1);color: red;}.ace-tm .ace_support.ace_function {color: rgb(60, 76, 114);}.ace-tm .ace_support.ace_constant {color: rgb(6, 150, 14);}.ace-tm .ace_support.ace_type,.ace-tm .ace_support.ace_class {color: rgb(109, 121, 222);}.ace-tm .ace_keyword.ace_operator {color: rgb(104, 118, 135);}.ace-tm .ace_string {color: rgb(3, 106, 7);}.ace-tm .ace_comment {color: rgb(76, 136, 107);}.ace-tm .ace_comment.ace_doc {color: rgb(0, 102, 255);}.ace-tm .ace_comment.ace_doc.ace_tag {color: rgb(128, 159, 191);}.ace-tm .ace_constant.ace_numeric {color: rgb(0, 0, 205);}.ace-tm .ace_variable {color: rgb(49, 132, 149);}.ace-tm .ace_xml-pe {color: rgb(104, 104, 91);}.ace-tm .ace_entity.ace_name.ace_function {color: #0000A2;}.ace-tm .ace_heading {color: rgb(12, 7, 255);}.ace-tm .ace_list {color:rgb(185, 6, 144);}.ace-tm .ace_meta.ace_tag {color:rgb(0, 22, 142);}.ace-tm .ace_string.ace_regex {color: rgb(255, 0, 0)}.ace-tm .ace_marker-layer .ace_selection {background: rgb(181, 213, 255);}.ace-tm.ace_multiselect .ace_selection.ace_start {box-shadow: 0 0 3px 0px white;}.ace-tm .ace_marker-layer .ace_step {background: rgb(252, 255, 0);}.ace-tm .ace_marker-layer .ace_stack {background: rgb(164, 229, 101);}.ace-tm .ace_marker-layer .ace_bracket {margin: -1px 0 0 -1px;border: 1px solid rgb(192, 192, 192);}.ace-tm .ace_marker-layer .ace_active-line {background: rgba(0, 0, 0, 0.07);}.ace-tm .ace_gutter-active-line {background-color : #dcdcdc;}.ace-tm .ace_marker-layer .ace_selected-word {background: rgb(250, 250, 255);border: 1px solid rgb(200, 200, 250);}.ace-tm .ace_indent-guide {background: url("...") right repeat-y;}
# /*# sourceURL=ace/css/ace-tm */</style><style id="ace_editor.css">.ace_br1 {border-top-left-radius    : 3px;}.ace_br2 {border-top-right-radius   : 3px;}.ace_br3 {border-top-left-radius    : 3px; border-top-right-radius:    3px;}.ace_br4 {border-bottom-right-radius: 3px;}.ace_br5 {border-top-left-radius    : 3px; border-bottom-right-radius: 3px;}.ace_br6 {border-top-right-radius   : 3px; border-bottom-right-radius: 3px;}.ace_br7 {border-top-left-radius    : 3px; border-top-right-radius:    3px; border-bottom-right-radius: 3px;}.ace_br8 {border-bottom-left-radius : 3px;}.ace_br9 {border-top-left-radius    : 3px; border-bottom-left-radius:  3px;}.ace_br10{border-top-right-radius   : 3px; border-bottom-left-radius:  3px;}.ace_br11{border-top-left-radius    : 3px; border-top-right-radius:    3px; border-bottom-left-radius:  3px;}.ace_br12{border-bottom-right-radius: 3px; border-bottom-left-radius:  3px;}.ace_br13{border-top-left-radius    : 3px; border-bottom-right-radius: 3px; border-bottom-left-radius:  3px;}.ace_br14{border-top-right-radius   : 3px; border-bottom-right-radius: 3px; border-bottom-left-radius:  3px;}.ace_br15{border-top-left-radius    : 3px; border-top-right-radius:    3px; border-bottom-right-radius: 3px; border-bottom-left-radius: 3px;}.ace_editor {position: relative;overflow: hidden;font: 12px/normal 'Monaco', 'Menlo', 'Ubuntu Mono', 'Consolas', 'source-code-pro', monospace;direction: ltr;text-align: left;-webkit-tap-highlight-color: rgba(0, 0, 0, 0);}.ace_scroller {position: absolute;overflow: hidden;top: 0;bottom: 0;background-color: inherit;-ms-user-select: none;-moz-user-select: none;-webkit-user-select: none;user-select: none;cursor: text;}.ace_content {position: absolute;box-sizing: border-box;min-width: 100%;contain: style size layout;}.ace_dragging .ace_scroller:before{position: absolute;top: 0;left: 0;right: 0;bottom: 0;content: '';background: rgba(250, 250, 250, 0.01);z-index: 1000;}.ace_dragging.ace_dark .ace_scroller:before{background: rgba(0, 0, 0, 0.01);}.ace_selecting, .ace_selecting * {cursor: text !important;}.ace_gutter {position: absolute;overflow : hidden;width: auto;top: 0;bottom: 0;left: 0;cursor: default;z-index: 4;-ms-user-select: none;-moz-user-select: none;-webkit-user-select: none;user-select: none;contain: style size layout;}.ace_gutter-active-line {position: absolute;left: 0;right: 0;}.ace_scroller.ace_scroll-left {box-shadow: 17px 0 16px -16px rgba(0, 0, 0, 0.4) inset;}.ace_gutter-cell {position: absolute;top: 0;left: 0;right: 0;padding-left: 19px;padding-right: 6px;background-repeat: no-repeat;}.ace_gutter-cell.ace_error {background-image: url("data:image/png;base64,...");background-repeat: no-repeat;background-position: 2px center;}.ace_gutter-cell.ace_warning {background-image: url("data:image/png;base64,...");background-position: 2px center;}.ace_gutter-cell.ace_info {background-image: url("...");background-position: 2px center;}.ace_dark .ace_gutter-cell.ace_info {background-image: url("...");}.ace_scrollbar {contain: strict;position: absolute;right: 0;bottom: 0;z-index: 6;}.ace_scrollbar-inner {position: absolute;cursor: text;left: 0;top: 0;}.ace_scrollbar-v{overflow-x: hidden;overflow-y: scroll;top: 0;}.ace_scrollbar-h {overflow-x: scroll;overflow-y: hidden;left: 0;}.ace_print-margin {position: absolute;height: 100%;}.ace_text-input {position: absolute;z-index: 0;width: 0.5em;height: 1em;opacity: 0;background: transparent;-moz-appearance: none;appearance: none;border: none;resize: none;outline: none;overflow: hidden;font: inherit;padding: 0 1px;margin: 0 -1px;contain: strict;-ms-user-select: text;-moz-user-select: text;-webkit-user-select: text;user-select: text;white-space: pre!important;}.ace_text-input.ace_composition {background: transparent;color: inherit;z-index: 1000;opacity: 1;}.ace_composition_placeholder { color: transparent }.ace_composition_marker { border-bottom: 1px solid;position: absolute;border-radius: 0;margin-top: 1px;}[ace_nocontext=true] {transform: none ...
# /*# sourceURL=ace/css/ace_editor.css */</style>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <title>webboard</title>
# <link href="/bootstrap-4.3.1/css/bootstrap.min.css" rel="stylesheet"/>
# <style>
# 		.modal {
# 		  padding: 0 !important;
# 		}
# 		.modal .modal-dialog {
# 		  width: 100%;
# 		  max-width: none;
# 		  height: 100%;
# 		  margin: 0;
# 		}
# 		.modal .modal-content {
# 		  height: 100%;
# 		  border: 0;
# 		  border-radius: 0;
# 		}
# 		.modal .modal-body {
# 		  overflow-y: auto;
# 		}
# 	</style>
# <script src="/js/jquery-3.2.1.min.js" type="text/javascript"></script>
# <script src="/bootstrap-4.3.1/js/bootstrap.min.js" type="text/javascript"></script>
# <script src="/js/mqttws31.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/ace.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-html.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-css.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-javascript.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-jsp.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-sql.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-java.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-xml.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-text.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-ejs.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-python.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-c_cpp.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-scala.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-golang.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-django.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/mode-r.js" type="text/javascript"></script>
# <script charset="utf-8" src="/ace/src/theme-eclipse.js" type="text/javascript"></script>
# </head>
# <body style="padding:3px">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md" style="">
# <div class="form-inline" style="margin-bottom:5px">
# <div class="menulist" style="margin-left:5px">
# <div class="btn-group">
# <a href="/home"><input type="button" value="home"/></a>
# </div>
# <div class="btn-group">
# <input class="menu_file_new" type="button" value="new"/>
# </div>
# <div class="btn-group">
# <input class="btn_file_save" style="display:none;" type="button" value="save"/>
# </div>
# <div class="btn-group">
# <a href="/filelist"><input type="button" value="filelist"/></a>
# </div>
# <div class="btn-group">
# <a href="/logout"><input type="button" value="logout"/></a>
# </div>
# </div>
# <div class="form-inline" style="margin-left:5px;">
# <strong>파일명 : </strong><label id="label_filename"></label>
# <input id="hidden_file_id" type="hidden"/>
# </div>   /
#
# 					<div class="form-inline">
# <strong>폰트크기 : </strong>
# <select class="" id="select_font_size">
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="11">11</option>
# <option value="12">12</option>
# <option value="13">13</option>
# <option value="14">14</option>
# <option value="15">15</option>
# <option selected="" value="16">16</option>
# <option value="17">17</option>
# <option value="18">18</option>
# <option value="19">19</option>
# <option value="20">20</option>
# <option value="21">21</option>
# <option value="22">22</option>
# <option value="23">23</option>
# <option value="24">24</option>
# <option value="25">25</option>
# <option value="26">26</option>
# <option value="27">27</option>
# <option value="28">28</option>
# <option value="29">29</option>
# <option value="30">30</option>
# <option value="31">31</option>
# <option value="32">32</option>
# <option value="33">33</option>
# <option value="34">34</option>
# <option value="35">35</option>
# <option value="36">36</option>
# <option value="37">37</option>
# <option value="38">38</option>
# <option value="39">39</option>
# <option value="40">40</option>
# <option value="41">41</option>
# <option value="42">42</option>
# <option value="43">43</option>
# <option value="44">44</option>
# <option value="45">45</option>
# <option value="46">46</option>
# <option value="47">47</option>
# <option value="48">48</option>
# <option value="49">49</option>
# <option value="50">50</option>
# <option value="51">51</option>
# <option value="52">52</option>
# <option value="53">53</option>
# <option value="54">54</option>
# <option value="55">55</option>
# <option value="56">56</option>
# <option value="57">57</option>
# <option value="58">58</option>
# <option value="59">59</option>
# <option value="60">60</option>
# <option value="61">61</option>
# <option value="62">62</option>
# <option value="63">63</option>
# <option value="64">64</option>
# <option value="65">65</option>
# <option value="66">66</option>
# <option value="67">67</option>
# <option value="68">68</option>
# <option value="69">69</option>
# <option value="70">70</option>
# <option value="71">71</option>
# <option value="72">72</option>
# <option value="73">73</option>
# <option value="74">74</option>
# <option value="75">75</option>
# <option value="76">76</option>
# <option value="77">77</option>
# <option value="78">78</option>
# <option value="79">79</option>
# <option value="80">80</option>
# <option value="81">81</option>
# <option value="82">82</option>
# <option value="83">83</option>
# <option value="84">84</option>
# <option value="85">85</option>
# <option value="86">86</option>
# <option value="87">87</option>
# <option value="88">88</option>
# <option value="89">89</option>
# <option value="90">90</option>
# <option value="91">91</option>
# <option value="92">92</option>
# <option value="93">93</option>
# <option value="94">94</option>
# <option value="95">95</option>
# <option value="96">96</option>
# <option value="97">97</option>
# <option value="98">98</option>
# <option value="99">99</option>
# <option value="100">100</option>
# <option value="101">101</option>
# <option value="102">102</option>
# <option value="103">103</option>
# <option value="104">104</option>
# <option value="105">105</option>
# <option value="106">106</option>
# <option value="107">107</option>
# <option value="108">108</option>
# <option value="109">109</option>
# <option value="110">110</option>
# <option value="111">111</option>
# <option value="112">112</option>
# <option value="113">113</option>
# <option value="114">114</option>
# <option value="115">115</option>
# <option value="116">116</option>
# <option value="117">117</option>
# <option value="118">118</option>
# <option value="119">119</option>
# <option value="120">120</option>
# <option value="121">121</option>
# <option value="122">122</option>
# <option value="123">123</option>
# <option value="124">124</option>
# <option value="125">125</option>
# <option value="126">126</option>
# <option value="127">127</option>
# <option value="128">128</option>
# <option value="129">129</option>
# <option value="130">130</option>
# <option value="131">131</option>
# <option value="132">132</option>
# <option value="133">133</option>
# <option value="134">134</option>
# <option value="135">135</option>
# <option value="136">136</option>
# <option value="137">137</option>
# <option value="138">138</option>
# <option value="139">139</option>
# <option value="140">140</option>
# <option value="141">141</option>
# <option value="142">142</option>
# <option value="143">143</option>
# <option value="144">144</option>
# <option value="145">145</option>
# <option value="146">146</option>
# <option value="147">147</option>
# <option value="148">148</option>
# <option value="149">149</option>
# <option value="150">150</option>
# <option value="151">151</option>
# <option value="152">152</option>
# <option value="153">153</option>
# <option value="154">154</option>
# <option value="155">155</option>
# <option value="156">156</option>
# <option value="157">157</option>
# <option value="158">158</option>
# <option value="159">159</option>
# <option value="160">160</option>
# <option value="161">161</option>
# <option value="162">162</option>
# <option value="163">163</option>
# <option value="164">164</option>
# <option value="165">165</option>
# <option value="166">166</option>
# <option value="167">167</option>
# <option value="168">168</option>
# <option value="169">169</option>
# <option value="170">170</option>
# <option value="171">171</option>
# <option value="172">172</option>
# <option value="173">173</option>
# <option value="174">174</option>
# <option value="175">175</option>
# <option value="176">176</option>
# <option value="177">177</option>
# <option value="178">178</option>
# <option value="179">179</option>
# <option value="180">180</option>
# <option value="181">181</option>
# <option value="182">182</option>
# <option value="183">183</option>
# <option value="184">184</option>
# <option value="185">185</option>
# <option value="186">186</option>
# <option value="187">187</option>
# <option value="188">188</option>
# <option value="189">189</option>
# <option value="190">190</option>
# <option value="191">191</option>
# <option value="192">192</option>
# <option value="193">193</option>
# <option value="194">194</option>
# <option value="195">195</option>
# <option value="196">196</option>
# <option value="197">197</option>
# <option value="198">198</option>
# <option value="199">199</option>
# <option value="200">200</option>
# </select>
# <div class="btn-group">
# 							 <label class="save_time"></label>
# </div>
# </div>
# </div>
# <div id="course_post"></div>
# <hr/>
# <div id="editor1"></div>
# <div id="content_data"></div>
# <div align="right" style="padding:10px;">
# <a class="top btn btn-outline-secondary btn-sm" href="#">Top</a>
# </div>
# <hr/>
# <div class="menulist">
# <div class="btn-group">
# <a href="/home"><input type="button" value="home"/></a>
# </div>
# <div class="btn-group">
# <input class="menu_file_new" type="button" value="new"/>
# </div>
# <div class="btn-group">
# <input class="btn_file_save" style="display:none;" type="button" value="save"/>
# </div>
# <div class="btn-group">
# <a href="/filelist"><input type="button" value="filelist"/></a>
# </div>
# <div class="btn-group">
# <a href="/logout"><input type="button" value="logout"/></a>
# </div>
# <div class="btn-group">
# <label class="save_time"></label>
# </div>
# <br/><br/>
# </div>
# </div>
# <div class="w-300" style="margin-left:0px">
# <div class="list-group" id="side_file_list"></div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="exampleModalLongTitle" class="modal fade bd-example-modal-lg" id="showContentModal" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-xl" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title">*** ESC키를 누르면 종료됩니다.</h5>
# <!-- <h5 class="modal-title" id="modal_body_display_title">title</h5> -->
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body" id="modal_body_display_content">
# 					내용이 없습니다.
# 				</div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="exampleModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="exampleModalLabel">파일추가</h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# <div class="form-inline" style="margin-bottom:5px">
# <label for="filename" style="width:90px">과정</label>
# <select class="form-control" id="course">
# <option selected="" value="bsit_20201223">bsit_20201223</option>
# </select>
# </div>
# <div class="form-inline" style="margin-bottom:5px">
# <label for="filename" style="width:90px">파일명</label>
# <input class="form-control" id="filename" placeholder="파일명" type="text"/>
# </div>
# <div class="form-inline" style="margin-bottom:5px">
# <label for="fileext" style="width:90px">파일종류</label>
# <select class="ui fluid dropdown form-control" id="fileext">
# <option value="java">java</option>
# <option value="jsp">jsp</option>
# <option value="html">html</option>
# <option value="css">css</option>
# <option value="js">js</option>
# <option value="sql">sql</option>
# <option value="xml">xml</option>
# <option value="txt">txt</option>
# <option value="ejs">ejs</option>
# <option value="py">py</option>
# <option value="c">c</option>
# <option value="cpp">cpp</option>
# <option value="scala">scala</option>
# <option value="golang">golang</option>
# <option value="django">django</option>
# <option value="r">r</option>
# </select>
# </div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-primary" id="btn_file_create" type="button">추가</button>
# <button class="btn btn-secondary" data-dismiss="modal" type="button">닫기</button>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	var init = 1;
# 	var client;
# 	var reconnectTimeout = 2000;
# 	var subscribe;
# 	var client_id = "wb_" + Math.floor(Date.now() / 1) + "_" + makeid() + "_" + parseInt(Math.random() * 10000, 10);
# 	//console.log(client_id);
#
# 	function makeid() {
# 	    var text = "";
# 	    var possible = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789";
# 	    for( let i=0; i < 3; i++ ) {
# 	        text += possible.charAt(Math.floor(Math.random() * possible.length));
# 	    }
# 	    return text;
# 	};
#
# 	function onConnect() {
# 		//console.log("onConnect");
# 		client.subscribe(subscribe, {qos: 0});
# 	};
#
# 	function onConnectionLost(responseObject) {
# 		console.log("connection lost: " + responseObject.errorMessage + ". Reconnecting");
# 		if ( responseObject.errorCode !== 0 ) {
# 			console.log("onConnectionLost:" + responseObject.errorMessage);
# 		}
# 		window.location.reload();
# 	};
#
#
# 	function onMessageArrived(message) {
# 		//console.log(message); // "wb/파일아이디/이메일"
# 		//console.log("onMessageArrived:"+message.payloadString);
# 		var t = message.destinationName;
# 		if( t.indexOf("/") >= 0 ){
# 			var ary = t.split("/");
# 			//console.log(ary[ary.length-1]);
# 			//이메일, 파일id, save
# 			$.ajaxCurrMessageList(ary[ary.length-1], ary[ary.length-2], message.payloadString);
# 		}
# 		//client.disconnect();
# 	};
#
#
# 	function setup(id, pw, addr, port, sub) {
# 		subscribe = sub;
# 		client = new Paho.MQTT.Client(addr, port, client_id);
#
# 		var options = {
#             timeout	 : 3,
#             /*useSSL: useTLS,
#             cleanSession: cleansession,*/
#             onSuccess: onConnect,
#             userName : id,
#             password : pw,
#             onFailure: function (message) {
#                 console.log("Connection failed: " + message.errorMessage + "Retrying");
#                 setTimeout(MQTTconnect, reconnectTimeout);
#             }
#         };
#
# 		client.onConnectionLost = onConnectionLost;
# 		client.onMessageArrived = onMessageArrived;
# 		client.connect(options);
# 	}
#
#
# 	function nl2br (str, is_xhtml) {
# 	    var breakTag = (is_xhtml || typeof is_xhtml === 'undefined') ? '<br />' : '<br>';
# 	    return (str + '').replace(/([^>\r\n]?)(\r\n|\n\r|\r|\n)/g, '$1'+ breakTag +'$2');
# 	};
#
# 	$(function() {
#
# 		var email = 'b20201223';
# 		var file_id = [];
# 		var file_name = [];
# 		var editor = [];
# 		var editor1;
#
# 		// -- 파일의 내용 가져오기
# 		$.ajaxFileOne = function(idx) {
# 			$('#content_data').empty();
#
# 			editor1 = ace.edit("editor1", {
# 		        theme		: "ace/theme/eclipse",
# 		        mode		: "ace/mode/html",
# 		        maxLines	: Infinity,
# 		        wrap		: true,
# 		        fontSize	: "16px",
# 		        autoScrollEditorIntoView	: true
# 		    });
#
# 			//$('#editor1').append(editor1);
#
# 			$.post("ajax_file_one.json", {id:file_id[idx]},function(ret){
# 				//console.log(ret);
# 				if(ret.chk == 1){
# 					var data = ret.docs;
# 					var len = data.length;
# 					if(len > 0) {
# 						var ext =  file_name[idx].split(".");
# 						if(ext.length >= 2){
# 							ext = ext[ext.length-1];
#
# 							if( ext == 'html') {
# 								editor1.session.setMode("ace/mode/html");
# 							}
# 							else if( ext == 'java') {
# 								editor1.session.setMode("ace/mode/java");
# 							}
# 							else if( ext == 'css') {
# 								editor1.session.setMode("ace/mode/css");
# 							}
# 							else if( ext == 'js') {
# 								editor1.session.setMode("ace/mode/javascript");
# 							}
# 							else if( ext == 'jsp') {
# 								editor1.session.setMode("ace/mode/jsp");
# 							}
# 							else if( ext == 'sql') {
# 								editor1.session.setMode("ace/mode/sql");
# 							}
# 							else if( ext == 'xml') {
# 								editor1.session.setMode("ace/mode/xml");
# 							}
# 							else if (ext == 'txt' || ext == 'text') {
# 								editor1.session.setMode("ace/mode/text");
# 							}
# 							else if (ext == 'ejs') {
# 								editor1.session.setMode("ace/mode/ejs");
# 							}
# 							else if (ext == 'py') {
# 								editor1.session.setMode("ace/mode/python");
# 							}
# 							else if (ext == 'c' || ext == 'cpp') {
# 								editor1.session.setMode("ace/mode/c_cpp");
# 							}
# 							else if (ext == 'scala') {
# 								editor1.session.setMode("ace/mode/scala");
# 							}
# 							else if (ext == 'golang') {
# 								editor1.session.setMode("ace/mode/golang");
# 							}
# 							else if (ext == 'django') {
# 								editor1.session.setMode("ace/mode/django");
# 							}
#
# 							else if (ext == 'r') {
# 								editor1.session.setMode("ace/mode/r");
# 							}
#
# 							$('#label_filename').text( file_name[idx] );
# 							$('#hidden_file_id').val( file_id[idx] );
#
# 							editor1.setValue( data[0].filedata );
# 							editor1.gotoLine( 0, 0 );
#
# 							if( data[0].email == email ) {
# 								$('.btn_file_save').attr('style', '');
# 								editor1.setReadOnly(false);
# 							}
# 							else {
# 								$('.btn_file_save').attr('style', 'display:none');
# 								editor1.setReadOnly(true);
# 							}
#
#
# 						}
# 					}
# 				}
# 				else if(ret.chk == 0) {
# 					window.location.href = "webboard";
# 				}
# 			},'json');
# 		};
#
#
# 		// -- 새로만들기 모달창 표시
# 		$('.menu_file_new').click(function() {
# 			$('#exampleModal').modal('show');
# 		});
#
#
# 		// -- 새로 만들기 버튼 수행
# 		$('#btn_file_create').click(function() {
# 			var na = $('#filename').val();
# 			var ty = $('#fileext').val();
# 			var co = $('#course').val();
# 			$.post('ajax_file_new_create.json', {type:ty, name:na, course:co}, function(data){
# 				//console.log(data);
# 				if(data.chk == 1){
# 					//$('#side_file_list').prepend('<div class="link item">'+data.ret[0].filename+'</div>');
# 					window.location.reload();
# 				}
# 			},'json');
# 		});
#
#
# 		// -- 목록 받아오기
# 		$.ajaxFileList = function(txt) {
#
# 			file_id = [];
# 			file_name = [];
#
# 			$.post("ajax_file_list.json", {text:txt}, function(ret) {
# 				// console.log("ret", ret);
#
# 				$('#side_file_list').empty();
#
# 				var data = ret.docs;
# 				var course_list_array = [];
# 				for(let i=0; i<data.length; i++){
# 					if (!course_list_array.includes(data[i].course)){
# 						course_list_array.push(data[i].course);
# 					}
# 				}
#
# 				var course_code = course_list_array[0];
# 				//console.log(course_code);
# 				if(ret.teacher_chk == 2){
# 					if(ret.select_course != 'all'){
# 						course_code = ret.select_course;
# 					}
#
# 					var option_tag = '<option style="font-size:14px" value="all">전체</option>'
# 					for (let i=0;i<course_list_array.length;i++){
# 						if( ret.select_course == course_list_array[i]){
# 							option_tag += '<option style="font-size:14px" value="'+course_list_array[i]+'" selected>'+course_list_array[i]+'</option>';
# 						}
# 						else{
# 							option_tag += '<option style="font-size:14px" value="'+course_list_array[i]+'">'+course_list_array[i]+'</option>';
# 						}
# 					}
#
# 					$('#side_file_list').append(
# 						'<select id="select_find_course" style="width:160px">' + option_tag + '</select>'
# 					);
# 				}
#
#
# 				$.post('/admin_v2/get_post_code.json', {course_code:course_code}, function(data){
#
# 					$('#course_post').empty();
# 					if(data.chk == 1){
# 						const str1 = data.ret.post_code;
# 						var arr = str1.split(',');
#
# 						//순서가 변경되는 것을 방지하기 위해 미리 a태그를 설정함.
# 						for(var i=0; i<arr.length; i++) {
# 							$('#course_post').append(
# 								'<a href="#" class="href_content_data" id="' + arr[i] + '">' +
# 									'<span class="badge badge-light" style="border:1px solid #cccccc" id="badge_' +  arr[i] +  '"></span>'+
# 								'</a>&nbsp;');
# 						}
#
# 						//span태그의 아이디 위치에 값을 추가함.
# 						for(var i=0; i<arr.length; i++) {
# 							$.ajax({
# 							    url				: '/admin_v2/blog_file_one.json',
# 							    async			: true,		// 동기 : false
# 							    type			: 'POST',
# 							    data			: { p_id : arr[i] },
# 							    dataType		: 'json',// xml, json, script, html
# 							    beforeSend		: function(jqXHR) {},
# 							    success			: function(data1) {
# 							    	//console.log(data1);
# 							    	//console.log(data1[0].tree_node_id , data1[0].title);
# 							    	if (data1.length > 0) {
# 							    		$('#badge_' + data1[0].tree_node_id).text(data1[0].title);
# 									}
# 							    },
# 							    error			: function(jqXHR) {},
# 							    complete		: function(jqXHR) {}
# 							});
# 						}
#
# 					}
# 				},'json');
#
# 				////////////////////////////////////////
#
#
# 				for(let i=0; i<data.length; i++){
# 					var cs = data[i].course;
# 					if(typeof cs !== "undefined"){
# 						if(cs.length > 14){
# 							cs = cs.substring( 0, 14 ) + "...";
# 						}
# 					}
#
# 					var btn_delete_tag = '';
# 					if (ret.teacher_chk == 2){
# 						btn_delete_tag = '<span class="badge bg-danger text-white btn_delete_file_one" myval="' + data[i]._id + '">삭제</span>'
# 					}
#
# 					$('#side_file_list').append(
# 						'<a href="#" class="list-group-item list-group-item-action filelist" style="padding:2px">' +
# 							'<small>' +
# 								'<div style="margin-bottom:-3px;"><b>' + data[i].filename + '</b></div>' +
# 								'<div>' + cs + '&nbsp;' + btn_delete_tag + '</div>' +
# 							'</small>' +
# 						'</a>');
#
# 					file_id.push(data[i]._id);
# 					file_name.push(data[i].filename);
# 				}
#
# 				$('.filelist').eq(0).click();
# 				//console.log(file_id[0]);
#
# 				if(init == 1) {
# 					$.post('/webboard/ajax_setup.json', {id:'abc'}, function(data) {
# 						setup(data.id, data.pw, data.addr, data.port, "wb/" + file_id[0] + "/#");
# 						init = 0;
# 					},'json');
# 				}
#
# 			},'json');
# 		};
# 		$.ajaxFileList('bsit_20201223');
#
#
# 		// -- content 클릭 시 수행
# 		$(document).on('click','.href_content_data', function(e) {
# 			var p_id =  $(this).attr('id');
# 			//console.log(p_id);
# 			editor = [];
# 			$.post('/home/ebook_file_data_list.json', {tree_node_id:p_id}, function(data){
# 				//console.log(data);
# 				var cnt = -1;
# 				$('#modal_body_display_content').empty();
# 				for (var i = 0; i < data.length; i++) {
# 					const mode = data[i].editor_mode;
#
# 					if( mode.startsWith('ace') ) {
# 						cnt++;
# 						if( mode.endsWith('text') ) {
# 							$('#modal_body_display_content').append('<div><p>' +  nl2br(data[i].editor_data) + '</p></div>');
# 						}
# 						else {
# 							$('#modal_body_display_content').append(
# 								'<div id="div_' + cnt + '">' +
# 									'<div id="editor_' + cnt + '" style="margin-top:0px">'+ '</div>'+ '<hr />'+
# 								'</div>'
# 							);
#
# 							editor[cnt] = ace.edit("editor_"+ cnt,	{
# 								theme 		: "ace/theme/eclipse",
# 								mode 		: data[i].editor_mode,
# 								maxLines 	: Infinity,
# 								wrap 		: true,
# 								fontSize 	: "16px",
# 								autoScrollEditorIntoView : true
# 							});
#
# 							editor[cnt].setValue(data[i].editor_data);
# 							editor[cnt].gotoLine(0,	0);
# 							editor[cnt].setReadOnly(true);
#
# 							editor[cnt].setHighlightActiveLine(false);
# 							editor[cnt].setHighlightGutterLine(false);
# 							editor[cnt].renderer.$cursorLayer.element.style.display = "none";
# 							//editor[cnt].setFontSize(16 + "px");
# 						}
# 					} else if( mode == 'tag_file' ) { // 이미지
# 						var html = '<div id="div_' + cnt + '" style="display:inline-block; width:100%;" >';
#
# 						if(data[i].editor_data != ""){
# 							html += '<img src="' + data[i].editor_data + '" id="image_view_' + cnt + '"  class="img-fluid" /><br />';
# 						}
# 						else {
# 							html += '<img src="/images/default.jpg" id="image_view_' + cnt + '" class="img-fluid" /><br />';
# 						}
#
# 						html += '<hr /></div>';
# 						$('#modal_body_display_content').append(html);
# 					}
# 				}
# 			},'json');
# 			$('#showContentModal').modal('show');
# 		});
#
#
# 		// -- 글자 크기 변경
# 		$(document).on('change','#select_font_size', function(e) {
# 			var size = $(this).val();
# 			//console.log(size);
# 			editor1.setFontSize(size + "px");
#
# 			for(var i=0;i<editor.length;i++){
# 				if(typeof editor[i] !== "undefined") {
# 					//console.log(editor[i]);
# 					editor[i].setFontSize(size+"px");
# 				}
# 			}
# 		});
#
#
# 		//-- 과정 변경시 수행
# 		$(document).on('change','#select_find_course', function(e) {
# 			var text = $(this).val()
# 			//alert(text)
# 			$.ajaxFileList(text);
# 		});
#
# 		// -- 삭제 시 수행
# 		$(document).on('click','.btn_delete_file_one', function(e) {
# 			var result = confirm('파일을 삭제하시겠습니까?');
# 			if(result) {
# 				var t_id = $(this).attr('myval');
# 				$.post('/webboard/ajax_file_data_delete.json', {t_id : t_id}, function(data){
# 					if(data.chk == 1){
# 						window.location.reload();
# 					}
# 				},'json');
# 			}
# 		});
#
#
# 		// -- 파일목록에서 파일 클릭 시
# 		$(document).on('click','.filelist', function(e) {
# 			$('.filelist').attr('class','list-group-item list-group-item-action filelist');
# 			$(this).attr('class','list-group-item list-group-item-action active filelist');
#
# 			var idx = $(this).index('.filelist');
# 			//console.log(file_id[idx]);
#
# 			if(typeof client !== "undefined") {
# 				client.subscribe("wb/" + file_id[idx] + "/#");
# 			}
#
# 			$.ajaxFileOne(idx);
# 		});
#
#
# 		// -- 저장하기 버튼 클릭
# 		$('.btn_file_save').click(function(){
# 			let id = $('#hidden_file_id').val();
# 			let data = editor1.getValue();
#
# 			$.post('ajax_file_data_update.json',{id:id, data:data}, function(data) {
# 				//console.log(data);
# 				var today = new Date();
# 				$('.save_time').text( "수정완료 : " + today.format('yyyy-MM-dd(KS) HH:mm:ss') );
#
# 				message = new Paho.MQTT.Message("save");
# 				message.destinationName = "wb/" + id + "/" + email;
# 				//console.log(message);
# 				client.send(message);
# 			}, 'json');
# 		});
#
#
#
# 		// -- top버튼 클릭시 가장 위쪽으로 이동
# 		$('.top' ).click( function() {
# 			$('html, body').animate({scrollTop : 0}, 400);
# 			return false;
# 		});
#
#
# 		// -- 날짜 포멧
# 		Date.prototype.format = function (f) {
# 		    if (!this.valueOf()) return " ";
# 			    var weekKorName = ["일요일", "월요일", "화요일", "수요일", "목요일", "금요일", "토요일"];
# 			    var weekKorShortName = ["일", "월", "화", "수", "목", "금", "토"];
# 			    var weekEngName = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"];
# 			    var weekEngShortName = ["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"];
# 			    var d = this;
# 			    return f.replace(/(yyyy|yy|MM|dd|KS|KL|ES|EL|HH|hh|mm|ss|a\/p)/gi, function ($1) {
# 			        switch ($1) {
# 			            case "yyyy": return d.getFullYear();
# 			            case "yy": return (d.getFullYear() % 1000).zf(2);
# 			            case "MM": return (d.getMonth() + 1).zf(2);
# 			            case "dd": return d.getDate().zf(2);
# 			            case "KS": return weekKorShortName[d.getDay()];
# 			            case "KL": return weekKorName[d.getDay()];
# 			            case "ES": return weekEngShortName[d.getDay()];
# 			            case "EL": return weekEngName[d.getDay()];
# 			            case "HH": return d.getHours().zf(2);
# 			            case "hh": return ((h = d.getHours() % 12) ? h : 12).zf(2);
# 			            case "mm": return d.getMinutes().zf(2);
# 			            case "ss": return d.getSeconds().zf(2);
# 			            case "a/p": return d.getHours() < 12 ? "AM" : "PM";
# 			            default: return $1;
# 			        }
# 			    });
# 			};
# 			String.prototype.string = function (len) { var s = '', i = 0; while (i++ < len) { s += this; } return s; };
# 			String.prototype.zf = function (len) { return "0".string(len - this.length) + this; };
# 			Number.prototype.zf = function (len) { return this.toString().zf(len);
# 		};
#
#
# 		$.ajaxCurrMessageList = function(topic, file_id, payload) {
# 			//if(topic != email && payload == 'save') {
# 			if(payload == 'save') {
# 				//console.log(topic,file_id, payload);
# 				if ( $('#hidden_file_id').val() == file_id) {
# 					$.post("ajax_file_one.json", {id:file_id},function(ret){
# 						//console.log(data);
# 						var data = ret.docs;
# 						editor1.setValue( data[0].filedata );
#
# 						var cursor = editor1.getCursorPosition();
# 						editor1.gotoLine(cursor.row, cursor.column);
# 					},'json');
# 				}
# 			}
# 		};
#
# 	});
# 	</script>
# </body></html>
